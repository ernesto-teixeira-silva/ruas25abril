# %% [markdown]
# # Introdução
#
# O presente notebook é efetuado no âmbito do desafio da 3ª edição do #PlottingGoodDSSG promovido por `Data Science for Social Good Portugal` e a elaboração do mesmo teve como propósito a aquisição de skills nas bibliotecas geopandas, folium e outras.
#
# Tentei replicar o notebook disponibilizado pela `dssg pt` e plotar alguns mapas, com especial foco no distrito de faro e criação os ficheiros html dos mapas.
#
# **Créditos:** dssg pt https://github.com/dssgPT/Plotting-Good-DSSG/tree/main/desafios/003_Liberdade_OSM

# %% [markdown]
# ## 1. Importação de bibliotecas e definição de funções

# %%
import geopandas as gpd
import pygeos as pygeos

from geopy import distance
from sklearn.preprocessing import LabelEncoder

import pandas as pd
from simpledbf import Dbf5

import folium
# Out:
# PyTables is not installed. No support for HDF output.
# SQLalchemy is not installed. No support for SQL output.

# %%
def calc_dist(df):
    x, y = df['centroid_x'], df['centroid_y']

    x_nn, y_nn = df['nn_centroid_x'], df['nn_centroid_y']

    return distance.distance((y, x), (y_nn, x_nn)).meters

# %% [markdown]
# ## 2. Ruas alusivas ao 25 de aril

# %% [markdown]
# ### 2.1 Carregamento do GeoDataFrame

# %%
roads_shp = "../dados_osm/portugal-latest-free.shp/gis_osm_roads_free_1.shp"

# %%
roads = gpd.read_file(roads_shp)

# %%
#roads.head()

# %% [markdown]
# ### 2.2 Expressões a pesquisar

# %%
freedom_roads = roads[(roads.name.str.contains("25 de Abril")) | (roads.name.str.contains("Liberdade")) | (
    roads.name.str.contains("Salgueiro Maia")) | (roads.name.str.contains("Capitães de Abril"))]
#freedom_roads

# %% [markdown]
# ### 2.3 Drop e renomeação de colunas

# %%
df_roads = freedom_roads[['osm_id', 'name', 'geometry']]
df_roads = df_roads.rename(columns={'name': 'rua'})
df_roads.head(2)
# Out:
#       osm_id                   rua  \
# 224  4453413  Avenida da Liberdade
# 237  4472168  Avenida da Liberdade
#
#                                               geometry
# 224  LINESTRING (-9.02960 39.75781, -9.02954 39.757...
# 237  LINESTRING (-9.03221 39.75903, -9.03204 39.758...

# %% [markdown]
# ### 2.4 Visualização das ruas no mapa

# %% [markdown]
# Cria ficheiro Geojson para plotar no folium

# %%
geojson_roads = df_roads.to_crs(epsg='4326').to_json()

# %%
mapa = folium.Map([37.125756, -7.649822],
                  zoom_start=8,
                  tiles='cartodbpositron')

points = folium.features.GeoJson(geojson_roads)

mapa.add_child(points)
mapa.save('../outputs/ruas_portugal.html')          # Ao criar na mesma celula o ficheiro html o mapa não é renderizado no IDE e o ficheiro .ipynb torna-se mais pequeno

# %% [markdown]
# ### 2.5 Criação de ficheiro html

# %%
mapa.save('../outputs/ruas_portugal.html')

# %% [markdown]
# ## 3. Concelhos e ruas

# %% [markdown]
# ### 3.1 Carregamento do GeoDataFrame dos concelhos

# %%
concelhos = gpd.read_file('../dados_osm/concelhos-shapefile/concelhos.shp',
                          SHAPE_RESTORE_SHX='YES')

# %%
concelhos.head()
# Out:
#    ID_0  ISO    NAME_0  ID_1 NAME_1  ID_2     NAME_2    HASC_2  CCN_2 CCA_2  \
# 0   182  PRT  Portugal     1  Évora     1      Évora  PT.EV.EV      0  0705
# 1   182  PRT  Portugal     1  Évora     2  Alandroal  PT.EV.AL      0  0701
# 2   182  PRT  Portugal     1  Évora     3  Arraiolos  PT.EV.AR      0  0702
# 3   182  PRT  Portugal     1  Évora     4      Borba  PT.EV.BO      0  0703
# 4   182  PRT  Portugal     1  Évora     5   Estremoz  PT.EV.ES      0  0704
#
#      TYPE_2     ENGTYPE_2 NL_NAME_2 VARNAME_2  \
# 0  Concelho  Municipality      None      None
# 1  Concelho  Municipality      None      None
# 2  Concelho  Municipality      None      None
# 3  Concelho  Municipality      None      None
# 4  Concelho  Municipality      None      None
#
#                                             geometry
# 0  POLYGON ((-7.79291 38.76507, -7.79287 38.76506...
# 1  POLYGON ((-7.25937 38.77351, -7.25921 38.77343...
# 2  POLYGON ((-7.88611 38.92495, -7.88580 38.92472...
# 3  POLYGON ((-7.46362 38.92344, -7.46344 38.92329...
# 4  POLYGON ((-7.52770 39.00080, -7.52765 39.00066...

# %% [markdown]
# ### 3.2 Concelhos do distrito de Faro

# %%
concelhos.loc[concelhos.NAME_1 =='Faro']
# Out:
#      ID_0  ISO    NAME_0  ID_1 NAME_1  ID_2                      NAME_2  \
# 120   182  PRT  Portugal     9   Faro   120                   Albufeira
# 121   182  PRT  Portugal     9   Faro   121                    Alcoutim
# 122   182  PRT  Portugal     9   Faro   121                    Alcoutim
# 123   182  PRT  Portugal     9   Faro   122                     Aljezur
# 124   182  PRT  Portugal     9   Faro   123                Castro Marim
# 125   182  PRT  Portugal     9   Faro   124                        Faro
# 126   182  PRT  Portugal     9   Faro   125                       Lagoa
# 127   182  PRT  Portugal     9   Faro   126                       Lagos
# 128   182  PRT  Portugal     9   Faro   127                       Loulé
# 129   182  PRT  Portugal     9   Faro   128                   Monchique
# 130   182  PRT  Portugal     9   Faro   129                       Olhão
# 131   182  PRT  Portugal     9   Faro   130                    Portimão
# 132   182  PRT  Portugal     9   Faro   131        São Brás de Alportel
# 133   182  PRT  Portugal     9   Faro   132                      Silves
# 134   182  PRT  Portugal     9   Faro   133               Vila do Bispo
# 135   182  PRT  Portugal     9   Faro   134  Vila Real de Santo António
#
#        HASC_2  CCN_2 CCA_2    TYPE_2     ENGTYPE_2 NL_NAME_2 VARNAME_2  \
# 120  PT.FA.AB      0  0801  Concelho  Municipality      None      None
# 121  PT.FA.AC      0  0802  Concelho  Municipality      None      None
# 122  PT.FA.AC      0  0814  Concelho  Municipality      None      None
# 123  PT.FA.AJ      0  0803  Concelho  Municipality      None      None
# 124  PT.FA.CM      0  0804  Concelho  Municipality      None      None
# 125  PT.FA.FA      0  0805  Concelho  Municipality      None      None
# 126  PT.FA.LA      0  0806  Concelho  Municipality      None      None
# 127  PT.FA.LS      0  0807  Concelho  Municipality      None      None
# 128  PT.FA.LO      0  0808  Concelho  Municipality      None      None
# 129  PT.FA.MO      0  0809  Concelho  Municipality      None      None
# 130  PT.FA.OL      0  0810  Concelho  Municipality      None      None
# 131  PT.FA.PO      0  0811  Concelho  Municipality      None      None
# 132  PT.FA.SB      0  0812  Concelho  Municipality      None      None
# 133  PT.FA.SI      0  0813  Concelho  Municipality      None      None
# 134  PT.FA.VB      0  0815  Concelho  Municipality      None      None
# 135  PT.FA.VS      0  0816  Concelho  Municipality      None      None
#
#                                               geometry
# 120  MULTIPOLYGON (((-8.28744 37.07175, -8.28748 37...
# 121  POLYGON ((-7.56960 37.52726, -7.56915 37.52715...
# 122  MULTIPOLYGON (((-7.61847 37.11625, -7.61847 37...
# 123  MULTIPOLYGON (((-8.90731 37.16032, -8.90735 37...
# 124  POLYGON ((-7.56433 37.39458, -7.56424 37.39458...
# 125  MULTIPOLYGON (((-7.88042 36.97347, -7.88042 36...
# 126  MULTIPOLYGON (((-8.44033 37.08669, -8.44038 37...
# 127  MULTIPOLYGON (((-8.66711 37.07995, -8.66716 37...
# 128  POLYGON ((-7.89775 37.41819, -7.89752 37.41811...
# 129  POLYGON ((-8.56828 37.41016, -8.56753 37.40986...
# 130  MULTIPOLYGON (((-7.81153 37.00708, -7.81153 37...
# 131  POLYGON ((-8.59216 37.27787, -8.59227 37.27719...
# 132  POLYGON ((-7.91230 37.12900, -7.91238 37.12902...
# 133  POLYGON ((-8.31367 37.43610, -8.31378 37.43516...
# 134  MULTIPOLYGON (((-8.91601 37.01462, -8.91608 37...
# 135  MULTIPOLYGON (((-7.41028 37.19887, -7.40910 37...

# %% [markdown]
# Por simples observação verifica-se que o concelho de ``Alcoutim`` (código ``ID_2`` de __121__) possui 2 registos. Correspondendo um ao código de concelho `CCA_2` de __0802__ e outro a __0814__.

# %% [markdown]
# Vejamos se esta incoerência verifica-se noutros concelhos.

# %%
concelhos.groupby(['NAME_2'])['NAME_2'].count(
).sort_values(ascending=False).head()
# Out:
# NAME_2
# Braga       2
# Lagoa       2
# Calheta     2
# Alcoutim    2
# Abrantes    1
# Name: NAME_2, dtype: int64

# %%
concelhos.loc[concelhos.NAME_2.isin(
    ['Braga', 'Lagoa', 'Calheta', 'Alcoutim'])].sort_values('NAME_2')
# Out:
#      ID_0  ISO    NAME_0  ID_1   NAME_1  ID_2    NAME_2    HASC_2  CCN_2  \
# 121   182  PRT  Portugal     9     Faro   121  Alcoutim  PT.FA.AC      0
# 122   182  PRT  Portugal     9     Faro   121  Alcoutim  PT.FA.AC      0
# 68    182  PRT  Portugal     5    Braga    69     Braga  PT.BR.BR      0
# 69    182  PRT  Portugal     5    Braga    69     Braga  PT.BR.BR      0
# 34    182  PRT  Portugal     3   Azores    35   Calheta  PT.AC.CA      0
# 183   182  PRT  Portugal    13  Madeira   182   Calheta  PT.MA.CT      0
# 37    182  PRT  Portugal     3   Azores    38     Lagoa  PT.AC.LG      0
# 126   182  PRT  Portugal     9     Faro   125     Lagoa  PT.FA.LA      0
#
#     CCA_2    TYPE_2     ENGTYPE_2 NL_NAME_2 VARNAME_2  \
# 121  0802  Concelho  Municipality      None      None
# 122  0814  Concelho  Municipality      None      None
# 68   0303  Concelho  Municipality      None      None
# 69   0308  Concelho  Municipality      None      None
# 34   4501  Concelho  Municipality      None      None
# 183  3101  Concelho  Municipality      None      None
# 37   4201  Concelho  Municipality      None      None
# 126  0806  Concelho  Municipality      None      None
#
#                                               geometry
# 121  POLYGON ((-7.56960 37.52726, -7.56915 37.52715...
# 122  MULTIPOLYGON (((-7.61847 37.11625, -7.61847 37...
# 68   POLYGON ((-8.35704 41.61721, -8.35661 41.61719...
# 69   POLYGON ((-8.31783 41.54539, -8.31739 41.54216...
# 34   MULTIPOLYGON (((-28.03560 38.60697, -28.03561 ...
# 183  MULTIPOLYGON (((-17.24440 32.78358, -17.24445 ...
# 37   POLYGON ((-25.55903 37.77534, -25.55883 37.775...
# 126  MULTIPOLYGON (((-8.44033 37.08669, -8.44038 37...

# %% [markdown]
# Conforme se observa a situação ocorre também nos concelhos de `Braga`, `Lagoa` e `Calheta`.
# Por consulta aos códigos dos concelhos em https://info.portaldasfinancas.gov.pt/pt/apoio_contribuinte/Documents/ListaFreguesiasVigentes_SFs.xls, por concatenação dos campos `Código Distrito` e `Código Concelho`, conclui-se que:
#
#     - 0814 - corresponde a Tavira
#     - 0308 - corresponde a Guimarães
#
# Relativamente a `Calheta` não se verifica anomalia pois existe concelhos com o mesmo nome nos Açores e na Madeira, o mesmo acontece com `Lagoa`, pois também temos concelhos com o mesmo nome nos Açores e no distrito de Faro.

# %% [markdown]
# Vamos corrigir o dataset

# %%
concelhos.loc[concelhos.CCA_2 == '0814', 'NAME_2'] = 'Tavira'
concelhos.loc[concelhos.CCA_2 == '0308', 'NAME_2'] = 'Guimarães'

# %% [markdown]
# ### 3.3 Drop e renomeação de colunas

# %%
df_concelhos = concelhos[['CCA_2', 'NAME_1','NAME_2', 'geometry']]
df_concelhos = df_concelhos.rename(
    columns={'NAME_1': 'distrito','NAME_2': 'concelho'})
df_concelhos
# Out:
#     CCA_2 distrito            concelho  \
# 0    0705    Évora               Évora
# 1    0701    Évora           Alandroal
# 2    0702    Évora           Arraiolos
# 3    0703    Évora               Borba
# 4    0704    Évora            Estremoz
# ..    ...      ...                 ...
# 303  1820    Viseu             Tarouca
# 304  1821    Viseu             Tondela
# 305  1822    Viseu  Vila Nova de Paiva
# 306  1823    Viseu               Viseu
# 307  1824    Viseu             Vouzela
#
#                                               geometry
# 0    POLYGON ((-7.79291 38.76507, -7.79287 38.76506...
# 1    POLYGON ((-7.25937 38.77351, -7.25921 38.77343...
# 2    POLYGON ((-7.88611 38.92495, -7.88580 38.92472...
# 3    POLYGON ((-7.46362 38.92344, -7.46344 38.92329...
# 4    POLYGON ((-7.52770 39.00080, -7.52765 39.00066...
# ..                                                 ...
# 303  POLYGON ((-7.72591 41.08079, -7.72442 41.08028...
# 304  POLYGON ((-8.12772 40.64028, -8.12751 40.64027...
# 305  POLYGON ((-7.77933 40.93439, -7.77835 40.93436...
# 306  POLYGON ((-7.80686 40.83789, -7.80653 40.83787...
# 307  POLYGON ((-8.04644 40.74920, -8.04635 40.74897...
#
# [308 rows x 4 columns]

# %% [markdown]
# ### 3.4 Visualização dos concelhos no mapa

# %%
geojson_concelhos = df_concelhos.to_crs(epsg='4326').to_json()

# %%
mapa_concelho = folium.Map([37.125756, -7.649822],
                           zoom_start=8,
                           tiles='cartodbpositron')

points_ruas = folium.features.GeoJson(geojson_roads)
points_concelhos = folium.features.GeoJson(geojson_concelhos)

mapa_concelho.add_child(points_ruas)
mapa_concelho.add_child(points_concelhos)
mapa_concelho.save('../outputs/ruas_e_concelhos_portugal.html') # Ao criar na mesma celula o ficheiro html o mapa não é renderizado no IDE e o ficheiro .ipynb torna-se mais pequeno

# %% [markdown]
# ### 3.5 Criação de ficheiro html

# %%
mapa_concelho.save('../outputs/ruas_e_concelhos_portugal.html')

# %% [markdown]
# ## 4. Algarve

# %% [markdown]
# ### 4.1 Merge `df_roads` e `df_concelhos`

# %%
df_roads_merged = df_roads.copy()
df_roads_merged['centroid_json'] = df_roads_merged.geometry.apply(lambda x: x.centroid)
df_roads_merged = df_roads_merged.sjoin(df_concelhos[['distrito','concelho', 'geometry']], how="left")
df_roads_merged = df_roads_merged[[
    'osm_id', 'rua', 'concelho', 'distrito', 'geometry', 'centroid_json']]

# %%
df_roads_merged.head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\ernes\OneDrive\Ambiente de Trabalho\projetos\projeto04_ruas_25_abril\notebook\ruas_25abril_algarve.ipynb Cell 43' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ernes/OneDrive/Ambiente%20de%20Trabalho/projetos/projeto04_ruas_25_abril/notebook/ruas_25abril_algarve.ipynb#ch0000042?line=0'>1</a> df_roads_merged.head(2)
#
# NameError: name 'df_roads_merged' is not defined

# %% [markdown]
# ### 4.2 Ruas e concelhos do Algarve

# %% [markdown]
# #### 4.2.1 Ruas do Algarve

# %%
df_ruas_algarve = df_roads_merged.loc[df_roads_merged.distrito == 'Faro'].drop(columns=
    'centroid_json')
df_ruas_algarve.head()
# Out:
#         osm_id                   rua concelho distrito  \
# 1951  18506519       Rua 25 de Abril    Lagos     Faro
# 6742  24005470       Rua 25 de Abril  Aljezur     Faro
# 7478  24717924      Rua da Liberdade    Lagos     Faro
# 7689  24824628    Largo da Liberdade    Lagos     Faro
# 7884  24841817  Rua 25 de Abril 1974    Lagos     Faro
#
#                                                geometry
# 1951  LINESTRING (-8.73729 37.08695, -8.73722 37.086...
# 6742  LINESTRING (-8.80039 37.30348, -8.80075 37.303...
# 7478  LINESTRING (-8.65473 37.14843, -8.65481 37.148...
# 7689  LINESTRING (-8.65546 37.14909, -8.65549 37.149...
# 7884  LINESTRING (-8.67211 37.10167, -8.67190 37.101...

# %% [markdown]
# #### 4.2.2 Concelhos do Algarve

# %%
df_concelhos_algarve = df_concelhos.loc[df_concelhos.distrito == 'Faro']
df_concelhos_algarve
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\ernes\OneDrive\Ambiente de Trabalho\projetos\projeto04_ruas_25_abril\notebook\ruas_25abril_algarve.ipynb Cell 48' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ernes/OneDrive/Ambiente%20de%20Trabalho/projetos/projeto04_ruas_25_abril/notebook/ruas_25abril_algarve.ipynb#ch0000047?line=0'>1</a> df_concelhos_algarve = df_concelhos.loc[df_concelhos.distrito == 'Faro']
#       <a href='vscode-notebook-cell:/c%3A/Users/ernes/OneDrive/Ambiente%20de%20Trabalho/projetos/projeto04_ruas_25_abril/notebook/ruas_25abril_algarve.ipynb#ch0000047?line=1'>2</a> df_concelhos_algarve
#
# NameError: name 'df_concelhos' is not defined

# %% [markdown]
# ### 4.3 Visualização ruas por concelho do Algarve

# %%
geojson_ruas_algarve = df_ruas_algarve.to_crs(epsg='4326').to_json()
geojson_conc_algarve = df_concelhos_algarve.to_crs(epsg='4326').to_json()

# %%
x = df_concelhos_algarve.centroid.x.mean()
y = df_concelhos_algarve.centroid.y.mean()
# Out:
# C:\Users\ernes\AppData\Local\Temp\ipykernel_3100\3584048611.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   x = df_concelhos_algarve.centroid.x.mean()
# C:\Users\ernes\AppData\Local\Temp\ipykernel_3100\3584048611.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   y = df_concelhos_algarve.centroid.y.mean()

# %%
mapa_algarve = folium.Map([y, x],
                           zoom_start=9,
                           tiles='cartodbpositron')

points_ruas = folium.features.GeoJson(geojson_ruas_algarve)
points_concelhos = folium.features.GeoJson(geojson_conc_algarve)

mapa_algarve.add_child(points_ruas)
mapa_algarve.add_child(points_concelhos)

mapa_algarve.save('../outputs/ruas_e_concelhos_algarve.html') # Ao criar o ficheiro html o mapa não é renderizado no IDE e o .ipynb fica mais pequeno

# %% [markdown]
# ### 4.4 Criação de ficheiro html

# %%
mapa_algarve.save('../outputs/ruas_e_concelhos_algarve.html')

# %% [markdown]
# ## 5. Ruas por concelho (Algarve)

# %% [markdown]
# ### 5.1 Carregamento do GeoDataFrame das Freguesias

# %%
freguesias = gpd.read_file(
    '../dados_osm/Cont_AAD_CAOP2021/Cont_AAD_CAOP2021.shp', SHAPE_RESTORE_SHX='YES')

# %%
freguesias.loc[freguesias.Concelho=='Tavira']
# Out:
#     Dicofre                                          Freguesia Concelho  \
# 117  081408                                        Santa Luzia   Tavira
# 147  081411  União das freguesias de Luz de Tavira e Santo ...   Tavira
# 266  081404                   Santa Catarina da Fonte do Bispo   Tavira
# 268  081410  União das freguesias de Conceição e Cabanas de...   Tavira
# 277  081412  União das freguesias de Tavira (Santa Maria e ...   Tavira
# 344  081401                                            Cachopo   Tavira
#
#     Distrito             TAA  Area_T_ha  Area_EA_ha  \
# 117     Faro  ÁREA PRINCIPAL     850.11      850.11
# 147     Faro  ÁREA PRINCIPAL    5991.23     5991.23
# 266     Faro  ÁREA PRINCIPAL   11758.82    11758.82
# 268     Faro  ÁREA PRINCIPAL    6944.44     6944.44
# 277     Faro  ÁREA PRINCIPAL   14799.45    14799.45
# 344     Faro  ÁREA PRINCIPAL   20352.65    20352.65
#
#                            Des_Simpli  \
# 117                       Santa Luzia
# 147     Luz de Tavira e Santo Estêvão
# 266  Santa Catarina da Fonte do Bispo
# 268     Conceição e Cabanas de Tavira
# 277   Tavira (Santa Maria e Santiago)
# 344                           Cachopo
#
#                                               geometry
# 117  POLYGON ((44124.924 -284909.918, 44001.315 -28...
# 147  POLYGON ((39830.680 -285449.774, 39857.751 -28...
# 266  POLYGON ((36801.125 -267518.604, 36788.657 -26...
# 268  POLYGON ((47725.490 -266319.773, 47726.940 -26...
# 277  POLYGON ((46705.715 -266056.914, 46701.996 -26...
# 344  POLYGON ((31092.759 -253628.910, 31092.629 -25...

# %% [markdown]
# ### 5.2 Merge das ruas do algarve com as freguesias

# %%
freguesias = freguesias.to_crs(epsg='4326')

# %%
df_ruas_algarve_merged = df_ruas_algarve.sjoin(
    freguesias[['Freguesia', 'geometry']])
df_ruas_algarve_merged.sample(3)
# Out:
#            osm_id                  rua   concelho distrito  \
# 213624  157157185     Rua da Liberdade    Aljezur     Faro
# 397477  252328072  Avenida 25 de Abril  Albufeira     Faro
# 804174  622463659      Rua 25 de Abril      Olhão     Faro
#
#                                                  geometry  index_right  \
# 213624  LINESTRING (-8.77276 37.42876, -8.77276 37.428...          379
# 397477  LINESTRING (-8.25195 37.12868, -8.25360 37.129...          129
# 804174  LINESTRING (-7.87252 37.05574, -7.87252 37.055...           35
#
#         Freguesia
# 213624   Odeceixe
# 397477  Ferreiras
# 804174     Pechão

# %%
len(df_ruas_algarve_merged)
# Out:
# 285

# %% [markdown]
# ### 5.3 Drop registos em duplicado

# %%
ruas_unicas_freguesia = df_ruas_algarve_merged.drop_duplicates(
    ['rua', 'concelho', 'Freguesia'])
ruas_unicas_freguesia
# Out:
#            osm_id                      rua       concelho distrito  \
# 1951     18506519          Rua 25 de Abril          Lagos     Faro
# 464633  300140567    Travessa da Liberdade          Lagos     Faro
# 464732  300140671  Rua Bairro da Liberdade          Lagos     Faro
# 6742     24005470          Rua 25 de Abril        Aljezur     Faro
# 11655    27739410       Largo da Liberdade        Aljezur     Faro
# ...           ...                      ...            ...      ...
# 395641  251153341       Largo da Liberdade        Aljezur     Faro
# 624706  416250980          Rua 25 de Abril       Alcoutim     Faro
# 684614  462739812          Rua 25 de Abril  Vila do Bispo     Faro
# 806536  625139868        Largo 25 de Abril          Olhão     Faro
# 888190  737868244          Rua 25 de Abril       Portimão     Faro
#
#                                                  geometry  index_right  \
# 1951    LINESTRING (-8.73729 37.08695, -8.73722 37.086...          120
# 464633  LINESTRING (-8.73694 37.10275, -8.73684 37.102...          120
# 464732  LINESTRING (-8.73781 37.10241, -8.73740 37.102...          120
# 6742    LINESTRING (-8.80039 37.30348, -8.80075 37.303...          342
# 11655   LINESTRING (-8.80361 37.31654, -8.80358 37.316...          342
# ...                                                   ...          ...
# 395641  LINESTRING (-8.86127 37.19569, -8.86125 37.195...          264
# 624706  LINESTRING (-7.47136 37.47201, -7.47137 37.471...          383
# 684614  LINESTRING (-8.90967 37.08204, -8.90905 37.08202)          134
# 806536  LINESTRING (-7.82152 37.05751, -7.82155 37.057...           55
# 888190  LINESTRING (-8.59429 37.13102, -8.59450 37.13125)          135
#
#                                          Freguesia
# 1951                                           Luz
# 464633                                         Luz
# 464732                                         Luz
# 6742                                       Aljezur
# 11655                                      Aljezur
# ...                                            ...
# 395641                                    Bordeira
# 624706  União das freguesias de Alcoutim e Pereiro
# 684614                   Vila do Bispo e Raposeira
# 806536                                     Quelfes
# 888190                                       Alvor
#
# [91 rows x 7 columns]

# %% [markdown]
# ### 5.4 Qtd de ruas por concelho

# %%
for index, concelho in df_concelhos_algarve.iterrows():
    
    qtd_ruas = len(ruas_unicas_freguesia[ruas_unicas_freguesia.intersects(
        concelho.geometry)])

    df_concelhos_algarve.loc[index, 'ruas'] = qtd_ruas
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\ernes\OneDrive\Ambiente de Trabalho\projetos\projeto04_ruas_25_abril\notebook\ruas_25abril_algarve.ipynb Cell 66' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ernes/OneDrive/Ambiente%20de%20Trabalho/projetos/projeto04_ruas_25_abril/notebook/ruas_25abril_algarve.ipynb#ch0000061?line=0'>1</a> for index, concelho in df_concelhos_algarve.iterrows():
#       <a href='vscode-notebook-cell:/c%3A/Users/ernes/OneDrive/Ambiente%20de%20Trabalho/projetos/projeto04_ruas_25_abril/notebook/ruas_25abril_algarve.ipynb#ch0000061?line=2'>3</a>     qtd_ruas = len(ruas_unicas_freguesia[ruas_unicas_freguesia.intersects(
#       <a href='vscode-notebook-cell:/c%3A/Users/ernes/OneDrive/Ambiente%20de%20Trabalho/projetos/projeto04_ruas_25_abril/notebook/ruas_25abril_algarve.ipynb#ch0000061?line=3'>4</a>         concelho.geometry)])
#       <a href='vscode-notebook-cell:/c%3A/Users/ernes/OneDrive/Ambiente%20de%20Trabalho/projetos/projeto04_ruas_25_abril/notebook/ruas_25abril_algarve.ipynb#ch0000061?line=5'>6</a>     df_concelhos_algarve.loc[index, 'ruas'] = qtd_ruas
#
# NameError: name 'df_concelhos_algarve' is not defined

# %% [markdown]
# ### 5.5 Carregamento da qtd ruas no mapa

# %%
for _, concelho in df_concelhos_algarve.iterrows():

    concelho_geojson = folium.features.GeoJson(concelho.geometry,
    style_function = lambda feature: {'color': 'blue', 'weight': 2,
                                      'fillOpacity': 0.1})

    popup = folium.Popup("""
    {}<br> {} ruas""".format(concelho.concelho, str(int(concelho.ruas))), max_width=300)
    popup.add_to(concelho_geojson)

    concelho_geojson.add_to(mapa_algarve)

# %% [markdown]
# ### 5.6 Visualização do mapa e criação de ficheiro html

# %%
#mapa_algarve  # Renderiza o mapa no IDE (mas torna o notebook mais pesado)

# %%
mapa_algarve.save('../outputs/algarve_total.html')
